# %%
import pypsa 
import pandas as pd
import matplotlib.pyplot as plt

# %%
net = pypsa.Network('../output_networks/zonal_no_links.nc')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, generators, links, loads, storage_units

# %%
net.buses_t.marginal_price.plot()
# Out:
# <Axes: xlabel='snapshot'>

# %%
net.plot()
# Out:
# C:\Users\wouterko\AppData\Local\Temp\ipykernel_16588\4026794000.py:1: DeprecatedWarning:
#
# plot is deprecated as of 0.34 and will be removed in 1.0. Use `n.plot.map()` as a drop-in replacement instead.
#
# WARNING:pypsa.plot.maps.static:Cartopy is not available. Falling back to non-geographic plotting.
# WARNING:pypsa.plot.maps.static:Cartopy needs to be installed to use `geomap=True`.
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x1d13cf312d0>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x1d13abdd450>},
#  'flows': {}}

# %%
nodal_net = pypsa.Network("../input_networks/pypsa-eur_central_northern/nodal.nc")
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, generators, lines, links, loads, storage_units

# %%
nodal_net.plot()
# Out:
# C:\Users\wouterko\AppData\Local\Temp\ipykernel_16588\234401929.py:1: DeprecatedWarning:
#
# plot is deprecated as of 0.34 and will be removed in 1.0. Use `n.plot.map()` as a drop-in replacement instead.
#
# WARNING:pypsa.plot.maps.static:Cartopy is not available. Falling back to non-geographic plotting.
# WARNING:pypsa.plot.maps.static:Cartopy needs to be installed to use `geomap=True`.
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x1d13aca34d0>},
#  'branches': {'Line': <matplotlib.collections.LineCollection at 0x1d1395a0f10>,
#   'Link': <matplotlib.collections.LineCollection at 0x1d13acb5ad0>},
#  'flows': {}}

# %%
nodal_net.buses_t.marginal_price.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 nodal_net.buses_t.marginal_price.plot()
#
# File c:\Users\wouterko\AppData\Local\anaconda3\envs\fbmc\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\wouterko\AppData\Local\anaconda3\envs\fbmc\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
